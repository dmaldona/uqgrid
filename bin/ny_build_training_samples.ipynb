# %%
import itertools
import numpy as np
import uuid
import json
import os
import copy
from joblib import Parallel, delayed
import scipy.io as scio

from uqgrid.simulation.dynamics import integrate_system
from uqgrid.simulation.config   import IntegrationConfig
from uqgrid.io.parse            import load_psse, add_dyr


def generate_perturbations(base_p, base_q,
                                *,
                                noise_type="normal", var=0.1,
                                rng=None, return_noise=False):
    """
    Apply per-bus noise -> return scaled loads.
    If return_noise=True, also return (p_noise, q_noise)

        P_scaled = base_p * (1 + p_noise)
        Q_scaled = base_q * (1 + q_noise)
    TODO: may need to change it so it's more flexible.
    """
    rng = np.random.default_rng() if rng is None else rng

    if noise_type == "normal":
        p_noise = rng.normal(0.0, var, size=base_p.shape)
        q_noise = rng.normal(0.0, var, size=base_q.shape)
    elif noise_type == "uniform":
        half = np.sqrt(3 * var)              # Var(U[-a,a]) = var
        p_noise = rng.uniform(-half, half, size=base_p.shape)
        q_noise = rng.uniform(-half, half, size=base_q.shape)
    elif noise_type == "none":
        p_noise = q_noise = np.zeros_like(base_p)
    else:
        raise ValueError(f"Unknown noise_type '{noise_type}'")

    p_scaled = base_p * (1.0 + p_noise)
    q_scaled = base_q * (1.0 + q_noise)

    if return_noise:
        return p_scaled, q_scaled, p_noise, q_noise
    return p_scaled, q_scaled


def sample_scenarios(n_samples, fault_locations, fault_impedances):
    return list(itertools.product(range(n_samples), fault_locations, fault_impedances))


def generate_metadata(scenarios):
    """
    Creates one UUID per scenario.  Metadata no longer contains 'base_load'.
    """
    metadata = {}
    for sample_idx, floc, fz in scenarios:
        sid = str(uuid.uuid4())
        metadata[sid] = {
            "sample_idx"     : sample_idx,
            "fault_location" : floc,
            "fault_impedance": fz,
        }
    with open("scenario_metadata.json", "w") as f:
        json.dump(metadata, f, indent=4)
    return metadata


def run_single_scenario(
        base_psys, scenario, scenario_id,
        base_p_load, base_q_load,
        base_p_gen,  base_q_gen,
        noise_type="normal", noise_var=0.1,
        balance_generation=False, 
        add_perturbations = True,
        fn = None):

    psys = copy.deepcopy(base_psys)

    #  Draw noise and obtain positive, scaled loads
    if add_perturbations:
        pL_scaled, qL_scaled, pL_noise, qL_noise = generate_perturbations(
            base_p_load, base_q_load,
            noise_type=noise_type, var=noise_var,
            return_noise=True)

        pG_scaled, qG_scaled, pG_noise, qG_noise = generate_perturbations(
            base_p_gen, base_q_gen,
            noise_type=noise_type, var=noise_var,
            return_noise=True)
    else:
        pL_scaled = base_p_load
        qL_scaled = base_q_load
        pG_scaled = base_p_gen
        qG_scaled = base_q_gen

    if balance_generation:
        sum_pL = np.sum(pL_scaled)
        sum_qL = np.sum(qL_scaled)
        sum_pG = np.sum(pG_scaled)
        sum_qG = np.sum(qG_scaled)

        if sum_pG != 0: pG_scaled *= (sum_pL / sum_pG)
        if sum_qG != 0: qG_scaled *= (sum_qL / sum_qG)

    psys.set_load_pq(pL_scaled, qL_scaled)
    psys.set_gen_pq(pG_scaled, qG_scaled)

    psys.add_busfault(scenario["fault_location"],
                      scenario["fault_impedance"], 0.25)
    psys.createYbusComplex()

    cfg = IntegrationConfig(
        tend=10.0, dt=1/120.0, power_injection=False,
        ton=0.25, toff=0.4, verbose=False, petsc=True
    )

    try:
        sim       = integrate_system(psys, cfg)
        diverged  = False
    except Exception:
        sim       = {"history": None, "tvec": None}
        diverged  = True

    os.makedirs("simulation_data", exist_ok=True)
    if fn is None:
        fn = f"simulation_data/scenario_{scenario_id}.npz"
        
    #  Draw noise and obtain positive, scaled loads
    if add_perturbations:
        np.savez_compressed(
            fn,
            history=sim["history"],
            tvec=sim["tvec"],
            p_load_scaled=pL_scaled, q_load_scaled=qL_scaled,
            p_load_noise =pL_noise,  q_load_noise =qL_noise,
            p_gen_scaled =pG_scaled, q_gen_scaled =qG_scaled,
            p_gen_noise  =pG_noise,  q_gen_noise  =qG_noise,
        )
    else:
        np.savez_compressed(
            fn,
            history=sim["history"],
            tvec=sim["tvec"],
            p_load_scaled=pL_scaled, q_load_scaled=qL_scaled,
            p_load_noise =0.0,  q_load_noise =0.0,
            p_gen_scaled =pG_scaled, q_gen_scaled =qG_scaled,
            p_gen_noise  =0.0,  q_gen_noise  =0.0,
        )
    
    return {"file": fn, "diverged": diverged}

def run_simulation_driver_batched_fixed_sample(
        raw, dyr, scenarios_metadata,
        *, noise_type="normal", noise_var=0.1,
        balance_generation=True, 
        n_jobs=-1, batch_size=10):

    simulation_log = {}
    starting_points = {}

    # Define the base values
    base_psys = load_psse(raw)
    add_dyr(base_psys, dyr)
    base_psys.export_state_metadata()

    base_p, base_q = base_psys.get_load_pq()
    base_pG, base_qG = base_psys.get_gen_pq()

    del base_psys
    
    print(f"base_p = {base_p}")
    print(f"base_pG = {base_pG}")

    # Define the base powers for each sample
    sim_per_scen = max(entry["sample_idx"] for entry in scenarios_metadata.values()) + 1
    for sim in range(sim_per_scen):
        pL_scaled, qL_scaled, pL_noise, qL_noise = generate_perturbations(
            base_p, base_q,
            noise_type=noise_type, var=noise_var,
            return_noise=True)

        pG_scaled, qG_scaled, pG_noise, qG_noise = generate_perturbations(
            base_pG, base_qG,
            noise_type=noise_type, var=noise_var,
            return_noise=True)

        starting_points[sim] = {
        "base_p": pL_scaled,
        "base_q": qL_scaled,
        "base_pG": pG_scaled,
        "base_qG": qG_scaled,
        }

    scenario_ids   = list(scenarios_metadata.keys())
    for batch_start in range(0, len(scenario_ids), batch_size):
        batch_ids = scenario_ids[batch_start : batch_start+batch_size]
        print(f"Processing batch {batch_start//batch_size + 1}"
            f" / {int(np.ceil(len(scenario_ids)/batch_size))}")

        base_psys = load_psse(raw)
        add_dyr(base_psys, dyr)
        base_psys.export_state_metadata()

        batch_args = [
            (base_psys, scenarios_metadata[sid], sid,
            starting_points[scenarios_metadata[sid]['sample_idx']]["base_p"], 
            starting_points[scenarios_metadata[sid]['sample_idx']]["base_q"], 
            starting_points[scenarios_metadata[sid]['sample_idx']]["base_pG"], 
            starting_points[scenarios_metadata[sid]['sample_idx']]["base_qG"], 
            noise_type, noise_var, 
            balance_generation, False)
            for sid in batch_ids
        ]

        batch_out = Parallel(n_jobs=n_jobs)(
            delayed(run_single_scenario)(*args) for args in batch_args)

        for sid, out in zip(batch_ids, batch_out):
                simulation_log[sid] = {**scenarios_metadata[sid], **out}

        del base_psys

    del starting_points

    with open("simulation_log.json", "w") as f:
        json.dump(simulation_log, f, indent=4)

    return simulation_log

def run_simulation_driver_batched_varried_sample(
        raw, dyr, scenarios_metadata,
        *, noise_type="normal", noise_var=0.1,
        balance_generation=True, 
        n_jobs=-1, batch_size=10):

    scenario_ids   = list(scenarios_metadata.keys())
    simulation_log = {}

    for batch_start in range(0, len(scenario_ids), batch_size):
        batch_ids = scenario_ids[batch_start : batch_start+batch_size]
        print(f"Processing batch {batch_start//batch_size + 1}"
              f" / {int(np.ceil(len(scenario_ids)/batch_size))}")

        base_psys = load_psse(raw)
        add_dyr(base_psys, dyr)
        base_psys.export_state_metadata()

        base_p, base_q = base_psys.get_load_pq()
        base_pG, base_qG = base_psys.get_gen_pq()
        
        print(f"base_p = {base_p}")
        print(f"base_pG = {base_pG}")

        batch_args = [
            (base_psys, scenarios_metadata[sid], sid,
             base_p, base_q, base_pG, base_qG, noise_type, noise_var, 
             balance_generation)
            for sid in batch_ids
        ]

        batch_out = Parallel(n_jobs=n_jobs)(
            delayed(run_single_scenario)(*args) for args in batch_args)

        for sid, out in zip(batch_ids, batch_out):
            simulation_log[sid] = {**scenarios_metadata[sid], **out}

        with open("simulation_log.json", "w") as f:
            json.dump(simulation_log, f, indent=4)

        del base_psys

    return simulation_log

def run_simulation_driver_batched(
    raw, dyr, scenarios_metadata,
    *, noise_type="normal", noise_var=0.1,
    balance_generation=True, 
    n_jobs=-1, batch_size=10, 
    fix_samp_per_scen = False):
        
    if fix_samp_per_scen:
        simulation_log = run_simulation_driver_batched_fixed_sample(
                                raw, dyr, scenarios_metadata,
                                noise_type=noise_type, noise_var=noise_var,
                                balance_generation=balance_generation, 
                                n_jobs=n_jobs, batch_size=batch_size)
    else:
        simulation_log = run_simulation_driver_batched_varried_sample(
                                raw, dyr, scenarios_metadata,
                                noise_type=noise_type, noise_var=noise_var,
                                balance_generation=balance_generation, 
                                n_jobs=n_jobs, batch_size=batch_size)

    return simulation_log

# %%
PowerGridModel = "IEEE-9"
if PowerGridModel == "IEEE-9":
    raw = "data/ieee9_v33.raw"
    dyr = "data/ieee9bus_gov.dyr"
    n_bus = 9
elif PowerGridModel == "IEEE-39":
    raw = "data/IEEE39_v33.raw"
    dyr = "data/IEEE39_gov.dyr"
    n_bus = 39
else:
    raise RuntimeError(f"{PowerGridModel} is an invalid model!")

number_of_samples = 30
fault_locations   = list(range(1, n_bus + 1))
fault_impedances  = [0.0001]

scenarios = sample_scenarios(
    number_of_samples, fault_locations, fault_impedances)
metadata  = generate_metadata(scenarios)

# %%
# noise settings
noise_type = "uniform"   # "normal", "uniform", "none", 
noise_var  = 0.50       # variance of the chosen distribution TODO: need to change this to be more flexible

simulation_log = run_simulation_driver_batched(
                        raw, dyr, metadata,
                        noise_type=noise_type, noise_var=noise_var,
                        n_jobs=1, batch_size=30, 
                        fix_samp_per_scen = True)
# Out:
# /usr/WS2/hiop/dane/project/scidac_2025/irabiel/WF_ACOPF/.venv/lib/python3.10/site-packages/uqgrid/io/parse.py:68: UserWarning: Transformer Magnetizing Impedance not Implemented
#   warnings.warn("Transformer Magnetizing Impedance not Implemented")
# base_p = [1.25 0.9  1.  ]
# base_pG = [0.71641 1.63    0.85   ]
# Processing batch 1 / 9
# Processing batch 2 / 9
# Processing batch 3 / 9
# Processing batch 4 / 9
# Processing batch 5 / 9
# Processing batch 6 / 9
# Processing batch 7 / 9
# Processing batch 8 / 9
# Processing batch 9 / 9

# %%
simulation_log
# Out:
# {'988e2e27-8aeb-4f61-866b-6f5777611278': {'sample_idx': 0,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_988e2e27-8aeb-4f61-866b-6f5777611278.npz',
#   'diverged': False},
#  'a7f4162f-ebbe-4f29-b809-16a837a95058': {'sample_idx': 0,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_a7f4162f-ebbe-4f29-b809-16a837a95058.npz',
#   'diverged': False},
#  'a78146bb-6a6a-42f1-8c18-a689c2d12808': {'sample_idx': 0,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_a78146bb-6a6a-42f1-8c18-a689c2d12808.npz',
#   'diverged': False},
#  '355eb50d-2948-4987-9300-7fdd573a48fc': {'sample_idx': 0,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_355eb50d-2948-4987-9300-7fdd573a48fc.npz',
#   'diverged': False},
#  '9477513f-598e-4fda-a801-96620c07ebc2': {'sample_idx': 0,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_9477513f-598e-4fda-a801-96620c07ebc2.npz',
#   'diverged': False},
#  '793f8b67-c34d-4965-8758-b682ae4399ed': {'sample_idx': 0,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_793f8b67-c34d-4965-8758-b682ae4399ed.npz',
#   'diverged': False},
#  '6c144929-0d93-4e48-8cbe-a3f81ecd3c0e': {'sample_idx': 0,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6c144929-0d93-4e48-8cbe-a3f81ecd3c0e.npz',
#   'diverged': False},
#  '5b649f75-3547-45bd-99db-0a1cd8168168': {'sample_idx': 0,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5b649f75-3547-45bd-99db-0a1cd8168168.npz',
#   'diverged': False},
#  '7f42aa3b-da23-476a-b34a-3259636d4d68': {'sample_idx': 0,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_7f42aa3b-da23-476a-b34a-3259636d4d68.npz',
#   'diverged': True},
#  '40ae371d-4f3e-4d3f-b972-80aa66f9e260': {'sample_idx': 1,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_40ae371d-4f3e-4d3f-b972-80aa66f9e260.npz',
#   'diverged': False},
#  '50bd4ca8-6726-4649-84a7-7a3280d116a9': {'sample_idx': 1,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_50bd4ca8-6726-4649-84a7-7a3280d116a9.npz',
#   'diverged': False},
#  'cea8023d-613e-464b-8804-ef9fabfbfd53': {'sample_idx': 1,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_cea8023d-613e-464b-8804-ef9fabfbfd53.npz',
#   'diverged': False},
#  '780556d3-4eb6-431d-8fa6-49bc3334ae24': {'sample_idx': 1,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_780556d3-4eb6-431d-8fa6-49bc3334ae24.npz',
#   'diverged': False},
#  '269d8c2a-e567-4e07-b650-258266757d65': {'sample_idx': 1,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_269d8c2a-e567-4e07-b650-258266757d65.npz',
#   'diverged': False},
#  '5262f0f5-dffc-4083-a6e3-2039e8510927': {'sample_idx': 1,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5262f0f5-dffc-4083-a6e3-2039e8510927.npz',
#   'diverged': False},
#  'ec4cb145-44cd-4e9b-86ed-0d7ca2614a2b': {'sample_idx': 1,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ec4cb145-44cd-4e9b-86ed-0d7ca2614a2b.npz',
#   'diverged': False},
#  'ae4981f0-1dc4-4459-b307-09198fb5eec1': {'sample_idx': 1,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario

#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0b539efd-0ac4-4fc0-83f1-83d2d00f9706.npz',
#   'diverged': False},
#  '45848893-1858-4b47-ac4d-2896e7e0dfe6': {'sample_idx': 5,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_45848893-1858-4b47-ac4d-2896e7e0dfe6.npz',
#   'diverged': True},
#  'fd92822f-8e21-48c2-a5b8-23d4a0bb5429': {'sample_idx': 6,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_fd92822f-8e21-48c2-a5b8-23d4a0bb5429.npz',
#   'diverged': False},
#  'e69e0777-d751-4a7e-8e9d-3e4effb60a97': {'sample_idx': 6,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_e69e0777-d751-4a7e-8e9d-3e4effb60a97.npz',
#   'diverged': False},
#  '88bdce74-1661-49db-9f15-7b5b7718313a': {'sample_idx': 6,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_88bdce74-1661-49db-9f15-7b5b7718313a.npz',
#   'diverged': False},
#  'c6abf40b-f5e3-4aac-98a5-405b0a354d49': {'sample_idx': 6,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c6abf40b-f5e3-4aac-98a5-405b0a354d49.npz',
#   'diverged': False},
#  '2778535c-86be-42aa-afb4-c811c6e22bd2': {'sample_idx': 6,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_2778535c-86be-42aa-afb4-c811c6e22bd2.npz',
#   'diverged': False},
#  '20223a2a-e381-43b5-b602-1bdf5146a62b': {'sample_idx': 6,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_20223a2a-e381-43b5-b602-1bdf5146a62b.npz',
#   'diverged': False},
#  '2ebb45c1-909a-499a-acef-54696aaf6eca': {'sample_idx': 6,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_2ebb45c1-909a-499a-acef-54696aaf6eca.npz',
#   'diverged': False},
#  '6e233d50-bc97-423d-9b01-6d6409f7ef08': {'sample_idx': 6,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6e233d50-bc97-423d-9b01-6d6409f7ef08.npz',
#   'diverged': False},
#  'f3e23f97-bc2d-4f2b-b376-2f2a42e1830c': {'sample_idx': 6,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f3e23f97-bc2d-4f2b-b376-2f2a42e1830c.npz',
#   'diverged': True},
#  'f7ef43c2-b07a-4cc0-a278-9361092f535e': {'sample_idx': 7,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f7ef43c2-b07a-4cc0-a278-9361092f535e.npz',
#   'diverged': False},
#  '912defca-370d-4bfb-b762-5d0afa7822df': {'sample_idx': 7,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_912defca-370d-4bfb-b762-5d0afa7822df.npz',
#   'diverged': False},
#  '500b5ffc-9db4-499a-8016-9ef57a25d20a': {'sample_idx': 7,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_500b5ffc-9db4-499a-8016-9ef57a25d20a.npz',
#   'diverged': False},
#  '8be94d26-64b3-4430-9208-720923687c79': {'sample_idx': 7,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_8be94d26-64b3-4430-9208-720923687c79.npz',
#   'diverged': False},
#  'bb479d8e-1818-4f6e-882e-c12b8a05580f': {'sample_idx': 7,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_bb479d8e-1818-4f6e-882e-c12b8a05580f.npz',
#   'diverged': False},
#  '20569514-53a1-43ef-8119-8eaea461645e': {'sample_idx': 7,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_20569514-53a1-43ef-8119-8eaea461645e.npz',
#   'diverged': False},
#  '182a2cb1-fb63-4966-9af4-9b7c1887f96f': {'sample_idx': 7,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_182a2cb1-fb63-4966-9af4-9b7c1887f96f.npz',
#   'diverged': False},
#  'bbea9373-262c-4a59-9904-c2df266b97fb': {'sample_idx': 7,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_bbea9373-262c-4a59-9904-c2df266b97fb.npz',
#   'diverged': False},
#  '59c4c56c-c6e8-4280-9169-1a1bb4548905': {'sample_idx': 7,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_59c4c56c-c6e8-4280-9169-1a1bb4548905.npz',
#   'diverged': True},
#  '44a2efc1-c4d8-43f7-a428-2899b1e28a8e': {'sample_idx': 8,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_44a2efc1-c4d8-43f7-a428-2899b1e28a8e.npz',
#   'diverged': False},
#  '46145835-14db-409d-9803-ea6cb5b96428': {'sample_idx': 8,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_46145835-14db-409d-9803-ea6cb5b96428.npz',
#   'diverged': False},
#  '0cca3e2b-191c-4e49-b341-34d57d74d034': {'sample_idx': 8,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0cca3e2b-191c-4e49-b341-34d57d74d034.npz',
#   'diverged': False},
#  'd7fe09cf-8608-4625-97cf-fc72df76efa9': {'sample_idx': 8,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d7fe09cf-8608-4625-97cf-fc72df76efa9.npz',
#   'diverged': False},
#  '88136ab1-d258-4679-aa27-103b9abf3d8a': {'sample_idx': 8,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_88136ab1-d258-4679-aa27-103b9abf3d8a.npz',
#   'diverged': False},
#  'bdf6277e-24e1-43c4-b62c-ae809f3f965d': {'sample_idx': 8,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_bdf6277e-24e1-43c4-b62c-ae809f3f965d.npz',
#   'diverged': False},
#  '0dc65558-1b9b-4376-aeb8-16102d2d033d': {'sample_idx': 8,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0dc65558-1b9b-4376-aeb8-16102d2d033d.npz',
#   'diverged': False},
#  'f0fb0106-5432-40e9-aee5-80a8113349ce': {'sample_idx': 8,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f0fb0106-5432-40e9-aee5-80a8113349ce.npz',
#   'diverged': False},
#  '119374f7-e4bc-47a7-864f-a20bb52faf26': {'sample_idx': 8,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_119374f7-e4bc-47a7-864f-a20bb52faf26.npz',
#   'diverged': True},
#  '843b9abc-6aa0-4ce6-b461-e80e123b09cd': {'sample_idx': 9,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_843b9abc-6aa0-4ce6-b461-e80e123b09cd.npz',
#   'diverged': False},
#  '23c025f4-bec4-4a30-a697-d7478672884b': {'sample_idx': 9,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_23c025f4-bec4-4a30-a697-d7478672884b.npz',
#   'diverged': False},
#  '406f8d60-4973-44d9-9a59-5467c95aed59': {'sample_idx': 9,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_406f8d60-4973-44d9-9a59-5467c95aed59.npz',
#   'diverged': False},
#  '24aa7ef5-7de8-4f38-8a3b-54a77c79c7e9': {'sample_idx': 9,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_24aa7ef5-7de8-4f38-8a3b-54a77c79c7e9.npz',
#   'diverged': False},
#  '27cbdb87-f397-4ce3-b8a7-94fbd60b3dd3': {'sample_idx': 9,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_27cbdb87-f397-4ce3-b8a7-94fbd60b3dd3.npz',
#   'diverged': False},
#  'efb01467-748e-44c3-851e-38424436bfef': {'sample_idx': 9,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_efb01467-748e-44c3-851e-38424436bfef.npz',
#   'diverged': False},
#  'd989ef54-8780-46f1-9765-46cd7f7a9ad9': {'sample_idx': 9,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d989ef54-8780-46f1-9765-46cd7f7a9ad9.npz',
#   'diverged': False},
#  '4840b2f7-5276-495e-ae54-89f902d7bf9d': {'sample_idx': 9,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4840b2f7-5276-495e-ae54-89f902d7bf9d.npz',
#   'diverged': False},
#  '5c614442-573a-44ed-83ed-77cf424d784d': {'sample_idx': 9,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5c614442-573a-44ed-83ed-77cf424d784d.npz',
#   'diverged': True},
#  '574efe0f-9da9-4e88-80d4-b0a5915e2e66': {'sample_idx': 10,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_574efe0f-9da9-4e88-80d4-b0a5915e2e66.npz',
#   'diverged': False},
#  'd28aa68f-1721-4934-9579-c4524d19db40': {'sample_idx': 10,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d28aa68f-1721-4934-9579-c4524d19db40.npz',
#   'diverged': False},
#  'c1eec86c-1d10-4eea-b759-f6681eb690ef': {'sample_idx': 10,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c1eec86c-1d10-4eea-b759-f6681eb690ef.npz',
#   'diverged': False},
#  '6c9de153-d090-45c2-8523-93c9509917ba': {'sample_idx': 10,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6c9de153-d090-45c2-8523-93c9509917ba.npz',
#   'diverged': False},
#  '7e429e22-ea62-4e16-a477-26c352394c95': {'sample_idx': 10,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_7e429e22-ea62-4e16-a477-26c352394c95.npz',
#   'diverged': False},
#  'cb16453f-ffb4-4cf9-9a66-9cc165c129c6': {'sample_idx': 10,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_cb16453f-ffb4-4cf9-9a66-9cc165c129c6.npz',
#   'diverged': False},
#  '27306f2d-7b18-4d54-8198-c20f83079bef': {'sample_idx': 10,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_27306f2d-7b18-4d54-8198-c20f83079bef.npz',
#   'diverged': False},
#  '026c51c8-461b-4d39-a776-e63f0e2db80e': {'sample_idx': 10,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_026c51c8-461b-4d39-a776-e63f0e2db80e.npz',
#   'diverged': False},
#  'aa882fbf-576f-414c-812f-83e2871caac8': {'sample_idx': 10,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_aa882fbf-576f-414c-812f-83e2871caac8.npz',
#   'diverged': True},
#  '49a79271-9346-4a9c-bdf1-4c246de060ff': {'sample_idx': 11,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_49a79271-9346-4a9c-bdf1-4c246de060ff.npz',
#   'diverged': False},
#  '04683bac-0f03-4965-9d52-f24d620ae4ff': {'sample_idx': 11,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_04683bac-0f03-4965-9d52-f24d620ae4ff.npz',
#   'diverged': False},
#  '199d9f75-617a-4173-ba79-540a6a0bb544': {'sample_idx': 11,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_199d9f75-617a-4173-ba79-540a6a0bb544.npz',
#   'diverged': False},
#  'bf2a19fe-6378-47aa-9483-34753a5073fc': {'sample_idx': 11,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_bf2a19fe-6378-47aa-9483-34753a5073fc.npz',
#   'diverged': False},
#  '22dd6622-dc59-4f96-b153-3427c4ba3471': {'sample_idx': 11,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_22dd6622-dc59-4f96-b153-3427c4ba3471.npz',
#   'diverged': False},
#  '5ee6a0e9-acbd-4145-bce4-861df8bebd00': {'sample_idx': 11,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5ee6a0e9-acbd-4145-bce4-861df8bebd00.npz',
#   'diverged': False},
#  '1bee4c7c-1bff-42cb-9a02-6a49585eebbd': {'sample_idx': 11,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1bee4c7c-1bff-42cb-9a02-6a49585eebbd.npz',
#   'diverged': False},
#  '9a6da1a4-a889-48e0-a2d5-e0ad02ac1261': {'sample_idx': 11,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_9a6da1a4-a889-48e0-a2d5-e0ad02ac1261.npz',
#   'diverged': False},
#  '91046c91-bea8-4f92-9b74-54bddddc576a': {'sample_idx': 11,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_91046c91-bea8-4f92-9b74-54bddddc576a.npz',
#   'diverged': True},
#  'ece360e4-10ff-4b23-87d2-43b97d28c991': {'sample_idx': 12,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ece360e4-10ff-4b23-87d2-43b97d28c991.npz',
#   'diverged': False},
#  'b9e5f287-2447-4913-b9bb-fd6b128bed46': {'sample_idx': 12,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_b9e5f287-2447-4913-b9bb-fd6b128bed46.npz',
#   'diverged': False},
#  'c7c1f894-195e-42d6-9ce6-746e6b2822aa': {'sample_idx': 12,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c7c1f894-195e-42d6-9ce6-746e6b2822aa.npz',
#   'diverged': False},
#  '96a645a1-b06f-45b8-9594-73a63540bca0': {'sample_idx': 12,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_96a645a1-b06f-45b8-9594-73a63540bca0.npz',
#   'diverged': False},
#  '56265749-6443-470e-8a77-afe5534806b4': {'sample_idx': 12,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_56265749-6443-470e-8a77-afe5534806b4.npz',
#   'diverged': False},
#  '2ee9a3e3-eafa-41b0-b4a6-e7df6e087f45': {'sample_idx': 12,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_2ee9a3e3-eafa-41b0-b4a6-e7df6e087f45.npz',
#   'diverged': False},
#  'dbf8aa16-d5ec-46f0-b430-310f09f126bd': {'sample_idx': 12,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_dbf8aa16-d5ec-46f0-b430-310f09f126bd.npz',
#   'diverged': False},
#  'ab7fadd2-c91f-4c4d-8370-5d43a08dc171': {'sample_idx': 12,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ab7fadd2-c91f-4c4d-8370-5d43a08dc171.npz',
#   'diverged': False},
#  '9beecf85-74ba-4d51-a17a-2c23fc137ee2': {'sample_idx': 12,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_9beecf85-74ba-4d51-a17a-2c23fc137ee2.npz',
#   'diverged': True},
#  'e41e111e-6668-4bde-b167-52df9379b068': {'sample_idx': 13,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_e41e111e-6668-4bde-b167-52df9379b068.npz',
#   'diverged': False},
#  'f441b7ac-8fc4-4709-844c-1656a469a28a': {'sample_idx': 13,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f441b7ac-8fc4-4709-844c-1656a469a28a.npz',
#   'diverged': False},
#  'd815afd6-5ac0-4244-806c-8e546e243a44': {'sample_idx': 13,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d815afd6-5ac0-4244-806c-8e546e243a44.npz',
#   'diverged': False},
#  '641074a8-3eef-46fa-a4f7-b2600859a3dc': {'sample_idx': 13,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_641074a8-3eef-46fa-a4f7-b2600859a3dc.npz',
#   'diverged': False},
#  '1878a704-029d-4c58-a47d-ee6ceb9dc9d3': {'sample_idx': 13,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1878a704-029d-4c58-a47d-ee6ceb9dc9d3.npz',
#   'diverged': False},
#  'c75f576b-f1ca-4ec9-8554-ad3b78759d41': {'sample_idx': 13,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c75f576b-f1ca-4ec9-8554-ad3b78759d41.npz',
#   'diverged': False},
#  '8463a6e5-6cfb-43e6-b99c-8b7cff9d0b99': {'sample_idx': 13,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_8463a6e5-6cfb-43e6-b99c-8b7cff9d0b99.npz',
#   'diverged': False},
#  '19802104-f740-4214-acc6-e13c3058b487': {'sample_idx': 13,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_19802104-f740-4214-acc6-e13c3058b487.npz',
#   'diverged': False},
#  '4676831e-aaa6-4989-a5e3-460c5ea51c53': {'sample_idx': 13,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4676831e-aaa6-4989-a5e3-460c5ea51c53.npz',
#   'diverged': True},
#  'b5368ce1-f2f1-490f-ae1c-f765633b114a': {'sample_idx': 14,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_b5368ce1-f2f1-490f-ae1c-f765633b114a.npz',
#   'diverged': False},
#  'c0ccc877-3c42-4401-bc12-f9bb2e9ca02a': {'sample_idx': 14,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c0ccc877-3c42-4401-bc12-f9bb2e9ca02a.npz',
#   'diverged': False},
#  '4862a19d-1d9a-46ac-a1bd-f01b659d102a': {'sample_idx': 14,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4862a19d-1d9a-46ac-a1bd-f01b659d102a.npz',
#   'diverged': False},
#  '03462aa8-8c82-48a0-a7a6-0c480f70874d': {'sample_idx': 14,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_03462aa8-8c82-48a0-a7a6-0c480f70874d.npz',
#   'diverged': False},
#  'f57bc1c9-65e1-43d9-a384-a2740a9969d0': {'sample_idx': 14,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f57bc1c9-65e1-43d9-a384-a2740a9969d0.npz',
#   'diverged': False},
#  '085843cb-f7d1-4f3d-ac8c-9a8a1913eeaa': {'sample_idx': 14,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_085843cb-f7d1-4f3d-ac8c-9a8a1913eeaa.npz',
#   'diverged': False},
#  '51d37e3b-7a74-4e83-b209-fa97384ade22': {'sample_idx': 14,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_51d37e3b-7a74-4e83-b209-fa97384ade22.npz',
#   'diverged': False},
#  'd200005d-6d43-45ef-b83a-b8690882f242': {'sample_idx': 14,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d200005d-6d43-45ef-b83a-b8690882f242.npz',
#   'diverged': False},
#  'e07ceece-ce74-4f6e-b04e-09b1b2ab8b7e': {'sample_idx': 14,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_e07ceece-ce74-4f6e-b04e-09b1b2ab8b7e.npz',
#   'diverged': True},
#  '4fbb4f27-f5b6-414f-b778-38e632237c74': {'sample_idx': 15,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4fbb4f27-f5b6-414f-b778-38e632237c74.npz',
#   'diverged': False},
#  'edc7f8e3-7102-48a0-82fd-8c8944f16918': {'sample_idx': 15,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_edc7f8e3-7102-48a0-82fd-8c8944f16918.npz',
#   'diverged': False},
#  '2d6ba703-3212-4695-80ca-772ab3016025': {'sample_idx': 15,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_2d6ba703-3212-4695-80ca-772ab3016025.npz',
#   'diverged': False},
#  '92b55265-96e1-4c68-a657-d85580e2b67b': {'sample_idx': 15,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_92b55265-96e1-4c68-a657-d85580e2b67b.npz',
#   'diverged': False},
#  '61ed1f39-8367-4572-8c36-cc387dbc1883': {'sample_idx': 15,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_61ed1f39-8367-4572-8c36-cc387dbc1883.npz',
#   'diverged': False},
#  '47196cb0-8d42-4972-b943-4fd453465be0': {'sample_idx': 15,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_47196cb0-8d42-4972-b943-4fd453465be0.npz',
#   'diverged': False},
#  'c4a0f0f8-4eb4-462f-9aae-0cedfd8c30a8': {'sample_idx': 15,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c4a0f0f8-4eb4-462f-9aae-0cedfd8c30a8.npz',
#   'diverged': False},
#  'ca7d33ea-bd62-454e-93d0-3b0f12674e8e': {'sample_idx': 15,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ca7d33ea-bd62-454e-93d0-3b0f12674e8e.npz',
#   'diverged': False},
#  '69ef16b0-6913-4129-952b-ba2f28fd86e5': {'sample_idx': 15,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_69ef16b0-6913-4129-952b-ba2f28fd86e5.npz',
#   'diverged': True},
#  '5d12ee91-6516-4462-b813-27aaeff09a4f': {'sample_idx': 16,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5d12ee91-6516-4462-b813-27aaeff09a4f.npz',
#   'diverged': False},
#  '5a5700b5-46f5-40d1-9367-6c88b3dda888': {'sample_idx': 16,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario

#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6ddcb978-c92a-4a41-997e-965d911e014a.npz',
#   'diverged': False},
#  '214f955b-43d0-443d-a663-5503ceabec53': {'sample_idx': 18,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_214f955b-43d0-443d-a663-5503ceabec53.npz',
#   'diverged': False},
#  '20f92163-f269-4808-821c-9e54d80ad7fa': {'sample_idx': 18,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_20f92163-f269-4808-821c-9e54d80ad7fa.npz',
#   'diverged': False},
#  '7291801e-2c5d-4f64-80cf-ca3415645e81': {'sample_idx': 18,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_7291801e-2c5d-4f64-80cf-ca3415645e81.npz',
#   'diverged': False},
#  '4c7b478d-76c7-4fa3-94ff-9dc52b884d4f': {'sample_idx': 18,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4c7b478d-76c7-4fa3-94ff-9dc52b884d4f.npz',
#   'diverged': False},
#  '040fa69f-6483-4cac-88cc-be8576ecb1a5': {'sample_idx': 18,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_040fa69f-6483-4cac-88cc-be8576ecb1a5.npz',
#   'diverged': False},
#  '08ad2160-6461-4e3b-8b28-39305d89687d': {'sample_idx': 18,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_08ad2160-6461-4e3b-8b28-39305d89687d.npz',
#   'diverged': True},
#  'c12021fd-65f5-40a6-ae26-82af3ee4db3c': {'sample_idx': 19,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c12021fd-65f5-40a6-ae26-82af3ee4db3c.npz',
#   'diverged': False},
#  'f2f9d984-2db8-4690-a3b9-1b9832f04657': {'sample_idx': 19,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f2f9d984-2db8-4690-a3b9-1b9832f04657.npz',
#   'diverged': False},
#  'efbbcf01-0511-4b9b-aad9-b0e065215b62': {'sample_idx': 19,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_efbbcf01-0511-4b9b-aad9-b0e065215b62.npz',
#   'diverged': False},
#  '1a88ee14-81f9-44ee-aa94-8a7cc5ca4cda': {'sample_idx': 19,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1a88ee14-81f9-44ee-aa94-8a7cc5ca4cda.npz',
#   'diverged': False},
#  'ea0e00cf-a091-4554-8d79-3afb9cc8d19e': {'sample_idx': 19,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ea0e00cf-a091-4554-8d79-3afb9cc8d19e.npz',
#   'diverged': False},
#  'd6ab28db-21ee-46b3-9b7a-91649af6aa4d': {'sample_idx': 19,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d6ab28db-21ee-46b3-9b7a-91649af6aa4d.npz',
#   'diverged': False},
#  '15e6bb7a-9b3c-424a-958a-22f20a527aa8': {'sample_idx': 19,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_15e6bb7a-9b3c-424a-958a-22f20a527aa8.npz',
#   'diverged': False},
#  '7757e9ed-f29f-4d23-9885-eee0e43bbf9f': {'sample_idx': 19,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_7757e9ed-f29f-4d23-9885-eee0e43bbf9f.npz',
#   'diverged': False},
#  'dcf1e9c0-57fa-4b5c-947a-711424ff8687': {'sample_idx': 19,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_dcf1e9c0-57fa-4b5c-947a-711424ff8687.npz',
#   'diverged': True},
#  'cb0f613b-6295-4675-96df-b09532f85d1c': {'sample_idx': 20,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_cb0f613b-6295-4675-96df-b09532f85d1c.npz',
#   'diverged': False},
#  '74527420-436d-4f57-9b94-03b22f64ad7d': {'sample_idx': 20,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_74527420-436d-4f57-9b94-03b22f64ad7d.npz',
#   'diverged': False},
#  '1e17cc01-a77b-4fb9-ab2b-e7493f0808da': {'sample_idx': 20,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1e17cc01-a77b-4fb9-ab2b-e7493f0808da.npz',
#   'diverged': False},
#  '418eee10-daa8-44e2-a13c-0e834b24308b': {'sample_idx': 20,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_418eee10-daa8-44e2-a13c-0e834b24308b.npz',
#   'diverged': False},
#  '56dac35b-236b-497c-9080-50338dabaca8': {'sample_idx': 20,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_56dac35b-236b-497c-9080-50338dabaca8.npz',
#   'diverged': False},
#  '520262e3-9fdc-496e-9140-89e3ad7e0df8': {'sample_idx': 20,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_520262e3-9fdc-496e-9140-89e3ad7e0df8.npz',
#   'diverged': False},
#  '498fc4c0-feb9-4603-b89f-987d424f4aaa': {'sample_idx': 20,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_498fc4c0-feb9-4603-b89f-987d424f4aaa.npz',
#   'diverged': False},
#  '818200c8-1ec9-4587-9859-ae9b1f8c0cd8': {'sample_idx': 20,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_818200c8-1ec9-4587-9859-ae9b1f8c0cd8.npz',
#   'diverged': False},
#  '15a17f43-bfce-4035-b14a-18537bd0b7e7': {'sample_idx': 20,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_15a17f43-bfce-4035-b14a-18537bd0b7e7.npz',
#   'diverged': True},
#  '58cad8cf-5f48-4ee3-8af0-f657220f92ba': {'sample_idx': 21,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_58cad8cf-5f48-4ee3-8af0-f657220f92ba.npz',
#   'diverged': False},
#  '97abdb5e-eab2-4355-a440-23338dabce73': {'sample_idx': 21,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_97abdb5e-eab2-4355-a440-23338dabce73.npz',
#   'diverged': False},
#  '3146ec2b-e068-4127-8058-178729ecf1d9': {'sample_idx': 21,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_3146ec2b-e068-4127-8058-178729ecf1d9.npz',
#   'diverged': False},
#  '1e91ac08-5673-42db-9587-b2b44c3969f7': {'sample_idx': 21,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1e91ac08-5673-42db-9587-b2b44c3969f7.npz',
#   'diverged': False},
#  '6e7689b0-9d87-457a-a790-f8b4acacd914': {'sample_idx': 21,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6e7689b0-9d87-457a-a790-f8b4acacd914.npz',
#   'diverged': False},
#  'eb48eb89-7290-43e3-a429-dbd605c2e7b4': {'sample_idx': 21,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_eb48eb89-7290-43e3-a429-dbd605c2e7b4.npz',
#   'diverged': False},
#  'd2441dcf-fbd2-484e-a3d5-1aabd5dd6d07': {'sample_idx': 21,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d2441dcf-fbd2-484e-a3d5-1aabd5dd6d07.npz',
#   'diverged': False},
#  '63ad0933-d8fd-4e42-8b62-5cc50c84565a': {'sample_idx': 21,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_63ad0933-d8fd-4e42-8b62-5cc50c84565a.npz',
#   'diverged': False},
#  'd07a3860-05db-4867-bd77-856e1e4b2072': {'sample_idx': 21,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d07a3860-05db-4867-bd77-856e1e4b2072.npz',
#   'diverged': True},
#  '2c8904fa-9b93-44c1-8754-554cda2b67b9': {'sample_idx': 22,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_2c8904fa-9b93-44c1-8754-554cda2b67b9.npz',
#   'diverged': False},
#  'f9936410-4140-43d1-a232-89ca7ebc8b96': {'sample_idx': 22,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f9936410-4140-43d1-a232-89ca7ebc8b96.npz',
#   'diverged': False},
#  '93d38257-7cc4-4840-9ef5-9def09d26ad2': {'sample_idx': 22,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_93d38257-7cc4-4840-9ef5-9def09d26ad2.npz',
#   'diverged': False},
#  'dd4a313e-b721-43ed-90f5-2a9f8ddfc596': {'sample_idx': 22,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_dd4a313e-b721-43ed-90f5-2a9f8ddfc596.npz',
#   'diverged': False},
#  '3003e195-e4ff-4ccf-b084-f392dfe6923f': {'sample_idx': 22,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_3003e195-e4ff-4ccf-b084-f392dfe6923f.npz',
#   'diverged': False},
#  '97993c16-2586-4f8b-adf7-964d19dded1b': {'sample_idx': 22,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_97993c16-2586-4f8b-adf7-964d19dded1b.npz',
#   'diverged': False},
#  '4aebe0de-f4dc-453d-a4ef-0e96b21a70fa': {'sample_idx': 22,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_4aebe0de-f4dc-453d-a4ef-0e96b21a70fa.npz',
#   'diverged': False},
#  'ad6f5b6f-0d81-41f8-807f-ff8b371704f7': {'sample_idx': 22,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ad6f5b6f-0d81-41f8-807f-ff8b371704f7.npz',
#   'diverged': False},
#  'b0858ffe-d12e-431c-a5c2-a15ed64e0e90': {'sample_idx': 22,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_b0858ffe-d12e-431c-a5c2-a15ed64e0e90.npz',
#   'diverged': True},
#  '115643fc-4248-4891-93c9-137bb4e035b7': {'sample_idx': 23,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_115643fc-4248-4891-93c9-137bb4e035b7.npz',
#   'diverged': False},
#  'fa6e99a0-c038-4101-888b-4c4375a750b0': {'sample_idx': 23,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_fa6e99a0-c038-4101-888b-4c4375a750b0.npz',
#   'diverged': False},
#  '53ea1dab-f1ce-4d7a-a21e-792f59362212': {'sample_idx': 23,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_53ea1dab-f1ce-4d7a-a21e-792f59362212.npz',
#   'diverged': False},
#  '6ed0e29f-5b7b-4031-8263-8fbe74e430f6': {'sample_idx': 23,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6ed0e29f-5b7b-4031-8263-8fbe74e430f6.npz',
#   'diverged': False},
#  'b701a2dd-d00b-4d13-9e7f-b91517b0515a': {'sample_idx': 23,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_b701a2dd-d00b-4d13-9e7f-b91517b0515a.npz',
#   'diverged': False},
#  '86f2d78e-12ac-47f8-9135-032137cda3c8': {'sample_idx': 23,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_86f2d78e-12ac-47f8-9135-032137cda3c8.npz',
#   'diverged': False},
#  '8ec3ff36-0749-482a-b5f8-733ac941b599': {'sample_idx': 23,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_8ec3ff36-0749-482a-b5f8-733ac941b599.npz',
#   'diverged': False},
#  'a9e6f56f-47cb-451a-b339-839d3c87f0b5': {'sample_idx': 23,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_a9e6f56f-47cb-451a-b339-839d3c87f0b5.npz',
#   'diverged': False},
#  'c08ae9ce-5592-45c6-8be0-1415ca92f6ed': {'sample_idx': 23,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c08ae9ce-5592-45c6-8be0-1415ca92f6ed.npz',
#   'diverged': True},
#  'ab103270-cf23-478a-beb7-17c916805684': {'sample_idx': 24,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ab103270-cf23-478a-beb7-17c916805684.npz',
#   'diverged': False},
#  'a532d572-8e2a-4b36-9f75-a3905b53130d': {'sample_idx': 24,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_a532d572-8e2a-4b36-9f75-a3905b53130d.npz',
#   'diverged': False},
#  '34580b06-806f-4f15-92a3-0b4513707feb': {'sample_idx': 24,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_34580b06-806f-4f15-92a3-0b4513707feb.npz',
#   'diverged': False},
#  'c65ad2f1-e0da-46c9-8544-3977e4e8ddb3': {'sample_idx': 24,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c65ad2f1-e0da-46c9-8544-3977e4e8ddb3.npz',
#   'diverged': False},
#  '30b306cc-8ae4-4e79-b318-8c8be9a223f8': {'sample_idx': 24,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_30b306cc-8ae4-4e79-b318-8c8be9a223f8.npz',
#   'diverged': False},
#  'ecd99496-9314-48bb-925e-a508924c5e0b': {'sample_idx': 24,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_ecd99496-9314-48bb-925e-a508924c5e0b.npz',
#   'diverged': False},
#  '501e84f5-5bd7-457c-9bf1-64ac56cd7ea3': {'sample_idx': 24,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_501e84f5-5bd7-457c-9bf1-64ac56cd7ea3.npz',
#   'diverged': False},
#  'f93bcfd9-9b43-415c-bd28-585b4c62ba29': {'sample_idx': 24,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_f93bcfd9-9b43-415c-bd28-585b4c62ba29.npz',
#   'diverged': False},
#  '6bbff005-be78-4df3-b94b-5455c932bc5c': {'sample_idx': 24,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6bbff005-be78-4df3-b94b-5455c932bc5c.npz',
#   'diverged': True},
#  '36a3432b-57bf-4ebe-8016-8bdc7f821dad': {'sample_idx': 25,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_36a3432b-57bf-4ebe-8016-8bdc7f821dad.npz',
#   'diverged': False},
#  '1a96f25b-7c94-41f2-9e4e-e36d57c6f533': {'sample_idx': 25,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_1a96f25b-7c94-41f2-9e4e-e36d57c6f533.npz',
#   'diverged': False},
#  'bae6e6df-f0ae-4eb7-92d0-7f5a5d514797': {'sample_idx': 25,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_bae6e6df-f0ae-4eb7-92d0-7f5a5d514797.npz',
#   'diverged': False},
#  '9c894168-709a-4870-b4a6-ef9362d9be48': {'sample_idx': 25,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_9c894168-709a-4870-b4a6-ef9362d9be48.npz',
#   'diverged': False},
#  'd2969805-28fe-4354-b790-a6f4326f303e': {'sample_idx': 25,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d2969805-28fe-4354-b790-a6f4326f303e.npz',
#   'diverged': False},
#  '92e27763-f4bf-491b-b460-ec1dd44b1d28': {'sample_idx': 25,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_92e27763-f4bf-491b-b460-ec1dd44b1d28.npz',
#   'diverged': False},
#  'db84f5b5-0bdc-4a12-bf32-2d30a31191ea': {'sample_idx': 25,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_db84f5b5-0bdc-4a12-bf32-2d30a31191ea.npz',
#   'diverged': False},
#  '688f87cc-e973-40d5-b74e-d2b219edadf5': {'sample_idx': 25,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_688f87cc-e973-40d5-b74e-d2b219edadf5.npz',
#   'diverged': False},
#  'c4752212-13cc-4442-81af-e239c76d3425': {'sample_idx': 25,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c4752212-13cc-4442-81af-e239c76d3425.npz',
#   'diverged': True},
#  '5ad06554-462c-42df-ac07-3c1f8b15aaa0': {'sample_idx': 26,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_5ad06554-462c-42df-ac07-3c1f8b15aaa0.npz',
#   'diverged': False},
#  'e6a0d68e-45e5-4dcf-a387-a0fc8a616855': {'sample_idx': 26,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_e6a0d68e-45e5-4dcf-a387-a0fc8a616855.npz',
#   'diverged': False},
#  'd7273a12-a5ef-4cb2-b942-7f55e0a5cf99': {'sample_idx': 26,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_d7273a12-a5ef-4cb2-b942-7f55e0a5cf99.npz',
#   'diverged': False},
#  '0ec3c769-0634-4da2-96aa-606296354cde': {'sample_idx': 26,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0ec3c769-0634-4da2-96aa-606296354cde.npz',
#   'diverged': False},
#  'c5233fa6-8b7b-4018-ba29-2e5ddaf82f38': {'sample_idx': 26,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_

#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_50baa1ac-131e-4523-ace8-936ad8fc4981.npz',
#   'diverged': False},
#  '0f0f87b8-1128-4825-952b-1ce2262e0553': {'sample_idx': 28,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0f0f87b8-1128-4825-952b-1ce2262e0553.npz',
#   'diverged': False},
#  '18a5429e-dc95-4062-a850-86485d289a37': {'sample_idx': 28,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_18a5429e-dc95-4062-a850-86485d289a37.npz',
#   'diverged': False},
#  'c2b971d6-24fd-46f0-8988-1e5d77dd6383': {'sample_idx': 28,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_c2b971d6-24fd-46f0-8988-1e5d77dd6383.npz',
#   'diverged': False},
#  'e4d80634-35fd-4731-875f-b68c6e4cb5ab': {'sample_idx': 28,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_e4d80634-35fd-4731-875f-b68c6e4cb5ab.npz',
#   'diverged': True},
#  '261742b4-128f-4c77-90c9-2404bb31efc3': {'sample_idx': 29,
#   'fault_location': 1,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_261742b4-128f-4c77-90c9-2404bb31efc3.npz',
#   'diverged': False},
#  '26d367e7-68c1-47c9-abb8-968ca4d256d5': {'sample_idx': 29,
#   'fault_location': 2,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_26d367e7-68c1-47c9-abb8-968ca4d256d5.npz',
#   'diverged': False},
#  '17eb7086-802f-44c8-9765-2d027b045677': {'sample_idx': 29,
#   'fault_location': 3,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_17eb7086-802f-44c8-9765-2d027b045677.npz',
#   'diverged': False},
#  '0b5f3042-b3a1-4228-93d3-159631903dac': {'sample_idx': 29,
#   'fault_location': 4,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_0b5f3042-b3a1-4228-93d3-159631903dac.npz',
#   'diverged': False},
#  'efb85db7-f6f4-40bb-8cb3-14864bffe3c1': {'sample_idx': 29,
#   'fault_location': 5,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_efb85db7-f6f4-40bb-8cb3-14864bffe3c1.npz',
#   'diverged': False},
#  '6cb386ff-5bfa-42eb-a969-b049b0c304f1': {'sample_idx': 29,
#   'fault_location': 6,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_6cb386ff-5bfa-42eb-a969-b049b0c304f1.npz',
#   'diverged': False},
#  'af0c7be4-35cb-4c4f-bbdf-23a57ecca2c6': {'sample_idx': 29,
#   'fault_location': 7,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_af0c7be4-35cb-4c4f-bbdf-23a57ecca2c6.npz',
#   'diverged': False},
#  '35346f0a-04ee-4851-9fc4-45bfb3ba05d4': {'sample_idx': 29,
#   'fault_location': 8,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_35346f0a-04ee-4851-9fc4-45bfb3ba05d4.npz',
#   'diverged': False},
#  '328a5bac-5e20-4faa-b592-94810282ba56': {'sample_idx': 29,
#   'fault_location': 9,
#   'fault_impedance': 0.0001,
#   'file': 'simulation_data/scenario_328a5bac-5e20-4faa-b592-94810282ba56.npz',
#   'diverged': True}}

# %%
fdsf = np.load("simulation_data/scenario_9f137d76-4bdf-4209-9ae1-be814d1c574b.npz",allow_pickle=True)

# %%
fdsf
# Out:
# NpzFile 'simulation_data/scenario_9f137d76-4bdf-4209-9ae1-be814d1c574b.npz' with keys: history, tvec, p_load_scaled, q_load_scaled, p_load_noise...

# %%
fdsf['q_gen_scaled']
# Out:
# array([-1.3617732 , -0.33503065,  0.54680385])

# %%
fdsf['p_gen_scaled']
# Out:
# array([0.70600815, 1.60633336, 0.8376585 ])

# %%
fdsf['p_load_scaled']
# Out:
# array([1.25, 0.9 , 1.  ])
